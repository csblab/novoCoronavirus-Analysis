# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import urllib.request
import numpy as np
import pandas as pd
from statsmodels.nonparametric.smoothers_lowess import lowess

# %%
# Load dataset from Johns Hopkins website
def load_url_as_df(url):
    """Loads csv data from a remote URL as a pandas Dataframe"""
    
    with urllib.request.urlopen(url) as stream:
        return pd.read_csv(stream, index_col='Country/Region')

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv'
df_confirmed = load_url_as_df(url)
df_confirmed.head()
# Out:
#                Province/State      Lat      Long  1/22/20  1/23/20  1/24/20  \
# Country/Region
# Thailand                  NaN  15.0000  101.0000        2        3        5
# Japan                     NaN  36.0000  138.0000        2        1        2
# Singapore                 NaN   1.2833  103.8333        0        1        3
# Nepal                     NaN  28.1667   84.2500        0        0        0
# Malaysia                  NaN   2.5000  112.5000        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20   ...     3/7/20  3/8/20  \
# Country/Region                                       ...
# Thailand              7        8        8       14   ...         50      50
# Japan                 2        4        4        7   ...        461     502
# Singapore             3        4        5        7   ...        138     150
# Nepal                 1        1        1        1   ...          1       1
# Malaysia              3        4        4        4   ...         93      99
#
#                 3/9/20  3/10/20  3/11/20  3/12/20  3/13/20  3/14/20  3/15/20  \
# Country/Region
# Thailand            50       53       59       70       75       82      114
# Japan              511      581      639      639      701      773      839
# Singapore          150      160      178      178      200      212      226
# Nepal                1        1        1        1        1        1        1
# Malaysia           117      129      149      149      197      238      428
#
#                 3/16/20
# Country/Region
# Thailand            147
# Japan               825
# Singapore           243
# Nepal                 1
# Malaysia            566
#
# [5 rows x 58 columns]

# %%
class TimeSeries:
    """TimeSeries
    
    Parameters
    ----------
    tseries: 1D array,
        the time-series as a 1D array
    t_origin: int,
        the time-stamp for the origin of the time-series. Default: 54
    
    Attributes
    ----------
    change: 1D array, length of tseries - 1
        the change in value of the time-series on given day.
    smooth: 1D array
        LOWESS smoothed time-series.
        frac: 0.15 (default)
        it  : 0    (default)
    """
    def __init__(self, tseries, t_origin=54):
        self.tseries = tseries
        self.tstamps = np.arange(t_origin, tseries.shape[0]+t_origin)
        
    def change(self, mode='ratio', smoothen=False):
        """change: change in value today relative value yesterday
        Arguments:
        =========
        mode: - 'ratio' (default): today / yesterday
              - 'difference'     : today - yesterday
        smoothen: - False (default) uses the input cumulative time-series
                  - True first smoothes the input cumulative time-series
        """
        if smoothen:
            data = self.smooth()
        else:
            data = self.tseries
        today     = np.copy(data)[1:]
        yesterday = np.copy(data[np.arange(data.size-1)])
        if(mode=='ratio'):
            return today/yesterday
        elif(mode=='difference'):
            return today-yesterday
    
    def smooth(self, frac=0.15, it=0): 
        """smoothen a time-series using LOWESS
        https://www.statsmodels.org/stable/generated/statsmodels.nonparametric.smoothers_lowess.lowess.html
        """
        tseries_smooth = lowess(self.tseries, self.tstamps, frac=frac, it=it)
        return tseries_smooth[:,1]

# %%
# Focus on one time-series: the worlwide cumulative total
confirmed_total = df_confirmed.sum()
#
ts_confirmed_total   = TimeSeries(confirmed_total.values)
tstamps              = ts_confirmed_total.tstamps
tseries              = ts_confirmed_total.tseries
tseries_smoothened   = ts_confirmed_total.smooth()
tseries_change_ratio = ts_confirmed_total.change(mode='ratio')
smooth_change_ratio  = ts_confirmed_total.change(mode='ratio', smoothen=True)
tseries_change_diff  = ts_confirmed_total.change(mode='difference')
smooth_change_diff   = ts_confirmed_total.change(mode='difference', smoothen=True)

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize=(12,4), dpi=180)
ax1.plot(tstamps, tseries, 'o', label='data', )
ax1.plot(tstamps, tseries_smoothened, '.-', label='smoothened')
ax1.set_xlabel('Days since first case')
ax1.set_ylabel('Confirmed cases')
ax1.grid()
ax1.legend()
ax2.plot(tstamps[1:], tseries_change_ratio, 'o', label='data', )
ax2.plot(tstamps[1:], smooth_change_ratio, '.-', label='smoothened')
ax2.set_xlabel('Days since first case')
ax2.set_ylabel('Confirmed cases (change ratio)')
ax2.grid()
ax2.legend()
ax3.plot(tstamps[1:], tseries_change_diff, 'o', label='data', )
ax3.plot(tstamps[1:], smooth_change_diff, '.-', label='smoothened')
ax3.set_xlabel('Days since first case')
ax3.set_ylabel('Confirmed cases (change diff)')
ax3.grid()
ax3.legend()
plt.tight_layout()
plt.show()
